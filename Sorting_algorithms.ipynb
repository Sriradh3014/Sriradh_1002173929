# %% [markdown]
# <a href="https://colab.research.google.com/github/Sriradh3014/Sriradh_1002173929/blob/main/Sorting_algorithms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import timeit
import random
import matplotlib.pyplot as plt

def bubble_sort(arr):
    for i in range(len(arr)):
        for j in range(0, len(arr)-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]
    return arr

def Insertion_sort(arr):
  for i in range(1, len(arr)):
    key = arr[i]
    j = i-1
    while j >= 0 and key < arr[j] :
            arr[j + 1] = arr[j]
            j -= 1
    arr[j + 1] = key
  return arr

def selection_sort(arr):
  for i in range(len(arr)):
    minimum_index = i
    for j in range(i+1, len(arr)):
        if arr[minimum_index] > arr[j]:
            minimum_index = j
    arr[i], arr[minimum_index] = arr[minimum_index], arr[i]
  return arr

def benchmark_sorting_algorithm(sort_function, input_size):
    setup_code = f"from __main__ import {sort_function}"
    stmt_code = f"{sort_function}({random.sample(range(0,20000), input_size)})"
    time_taken = timeit.timeit(stmt=stmt_code, setup=setup_code, number=1)

    return time_taken

input_sizes = [5, 10, 20, 50, 100, 200, 500, 1000,15000]

times = {}

algo=['bubble_sort','Insertion_sort','selection_sort']

color=['r','g','b']

for algo in algo:
  times[algo]=[]
  for size in input_sizes:
      time_taken = benchmark_sorting_algorithm(algo, size)
      times[algo].append(time_taken)


plt.plot(input_sizes, times['bubble_sort'],color=color[0], label='bubble_sort')
plt.plot(input_sizes, times['Insertion_sort'],color=color[1], label='Insertion_sort')
plt.plot(input_sizes, times['selection_sort'],color=color[2], label='selection_sort')


plt.xlabel('Input Size')
plt.ylabel('Time (s)')
plt.title('Benchmark')
plt.legend()
plt.show()
